# %%
# !pip install pennylane
# Out:
# Requirement already satisfied: pennylane in c:\users\dell\anaconda3\lib\site-packages (0.35.1)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (1.24.4)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (1.10.1)
# Requirement already satisfied: networkx in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (2.8.8)
# Requirement already satisfied: rustworkx in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (0.14.2)
# Requirement already satisfied: autograd in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (0.10.2)
# Requirement already satisfied: appdirs in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: semantic-version>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (2.10.0)
# Requirement already satisfied: autoray>=0.6.1 in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (0.6.7)
# Requirement already satisfied: cachetools in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (5.3.2)
# Requirement already satisfied: pennylane-lightning>=0.35 in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (0.35.1)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\lib\site-packages (from pennylane) (4.7.1)
# Requirement already satisfied: future>=0.15.2 in c:\users\dell\anaconda3\lib\site-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests->pennylane) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->pennylane) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->pennylane) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->pennylane) (2024.2.2)

# %%
import pennylane as qml
import pennylane.numpy as np
import networkx as nx
from pennylane.transforms import mitigate_with_zne
from matplotlib import pyplot as plt

# %%
graph = nx.Graph(((0, 1), (1, 2), (2, 0)))
from pennylane.qaoa import maxcut
hamiltonian_maxcut, hamiltonian_mixer = maxcut(graph)
nx.draw(graph, with_labels=True, font_weight='bold')

# %%
obs = []
coeffs = []

for edge in graph.edges():
    coeffs.extend([1.0, 1.0, 1.0])
    obs.extend([qml.PauliX(edge[0]) @ qml.PauliX(edge[1]),
                        qml.PauliY(edge[0]) @ qml.PauliY(edge[1]),
                        qml.PauliZ(edge[0]) @ qml.PauliZ(edge[1])])
H = qml.Hamiltonian(coeffs, obs)
print(H)
num_qubits = len(H.wires)
print("\nVector space dimension: ", num_qubits)
# Out:
#   (1.0) [X0 X1]
# + (1.0) [Y0 Y1]
# + (1.0) [Z0 Z1]
# + (1.0) [X0 X2]
# + (1.0) [Y0 Y2]
# + (1.0) [Z0 Z2]
# + (1.0) [X1 X2]
# + (1.0) [Y1 Y2]
# + (1.0) [Z1 Z2]
#
# Vector space dimension:  3

# %%
n_layers = 2
w1 = np.ones((num_qubits), requires_grad=True)
w2 = np.ones((n_layers, num_qubits - 1, 2), requires_grad=True)
def ansatz_cost(w1, w2):
    qml.SimplifiedTwoDesign(w1, w2, wires=range(num_qubits))
    return qml.expval(H)

print(qml.draw(ansatz_cost)(w1,w2))
# Out:
# 0: ─╭SimplifiedTwoDesign─┤ ╭<𝓗>
# 1: ─├SimplifiedTwoDesign─┤ ├<𝓗>
# 2: ─╰SimplifiedTwoDesign─┤ ╰<𝓗>

# %%
dev = qml.device("lightning.qubit", wires=num_qubits)
qn1 = qml.QNode(ansatz_cost,dev)
res1 = qn1(w1, w2)
res1
# Out:
# array(-0.03412382)

# %% [markdown]
# Let's optimize the square lattice using noise and mitigate using linear extrapolation of the zne method

# %%
noise_gate = qml.DepolarizingChannel #artificial noise
noise_strength = 0.025 #strength of kraus noise

dev_ideal = qml.device("default.mixed", wires=num_qubits) #comparative ideal noiseless device
dev_noisy = qml.transforms.insert(dev_ideal, noise_gate, noise_strength, position="all") #noisy device


scale_factors=[2]

qnode_ideal = qml.QNode(ansatz_cost, dev_ideal) # ideal qnode
qnode_noisy = qml.QNode(ansatz_cost, dev_noisy) #noisy qnode
qnode_mitigated = mitigate_with_zne(qnode_noisy,
    scale_factors=scale_factors,
    folding=qml.transforms.fold_global,
    extrapolate=qml.transforms.poly_extrapolate, extrapolate_kwargs={'order': 2}
) # mitigated qnode

# %%
print("Ideal QNode: ", qnode_ideal(w1, w2))
print("Mitigated QNode: ", qnode_mitigated(w1, w2))
print("Noisy QNode: ", qnode_noisy(w1, w2))
# Out:
# Ideal QNode:  -0.034123822718703
# Mitigated QNode:  0.01165246576646924
# Noisy QNode:  -0.013913501014359203

# %%
folded_circuits = [qml.transforms.fold_global(qnode_noisy, scale_factor) for scale_factor in scale_factors]
print(folded_circuits,"\n\n")

for i in range(len(folded_circuits)):
  drawing, ax = qml.draw_mpl(folded_circuits[i])(w1,w2)
  fig = drawing.figure
  """fig.set_figwidth(16)
  fig.set_figheight(2.5)"""
  drawing.show()
# Out:
# [<QNode: wires=3, device='default.mixed', interface='auto', diff_method='best'>]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3052\1059801168.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   drawing.show()

# %%
def VQE_run(cost_fn, max_iter, stepsize=0.1):
    """VQE Optimization loop"""
    opt = qml.SPSAOptimizer(maxiter= max_iter)

    # fixed initial guess
    w1 = np.ones((num_qubits), requires_grad=True)
    w2 = np.ones((n_layers, num_qubits - 1, 2), requires_grad=True)

    energy = []

    # Optimization loop
    for n in range(max_iter):
        (w1, w2), prev_energy = opt.step_and_cost(cost_fn, w1, w2)

        energy.append(prev_energy)
        if (n%50 == 0):
          print("Energy optimization at ",n,"th step is : ",energy[-1])

    energy.append(cost_fn(w1, w2)) # final addition to the last updated params
    print("Energy optimization at final step is : ",energy[-1],"\n")
    return energy # energy list


max_iter = 200

energy_ideal = VQE_run(qnode_ideal, max_iter)
energy_exact = np.min(np.linalg.eigvalsh(qml.matrix(H)))
print("Exact Ground state: ",energy_exact)
# Out:
# Energy optimization at  0 th step is :  -0.034123822718703
# Energy optimization at  50 th step is :  -2.9989256597921923
# Energy optimization at  100 th step is :  -2.999640038802923
# Energy optimization at  150 th step is :  -2.9996873958415105
# Energy optimization at final step is :  -2.9998030393783326
#
# Exact Ground state:  -3.0000000000000004

# %%
plt.figure(figsize=(10, 7))

plt.plot(energy_ideal, "-", label="VQE ideal", color = "m",linewidth = 0.9)
plt.plot(np.arange(stop=max_iter,step=1), [energy_exact]*max_iter, "-", label="E_exact", color = "r")
plt.legend(fontsize=10)

plt.xlabel("Iteration", fontsize=10)
plt.ylabel("Energy", fontsize=10)
plt.show()

# %%
energy_noisy = VQE_run(qnode_noisy, max_iter)
energy_mitigated = VQE_run(qnode_mitigated, max_iter)
# Out:
# Energy optimization at  0 th step is :  -0.013913501014359203
# Energy optimization at  50 th step is :  -2.043821640043949
# Energy optimization at  100 th step is :  -2.0665645019688053
# Energy optimization at  150 th step is :  -2.072641373338766
# Energy optimization at final step is :  -2.078002615337516
#
# Energy optimization at  0 th step is :  0.01165246576646924
# Energy optimization at  50 th step is :  -0.17802554493923628
# Energy optimization at  100 th step is :  -0.3356246472576218
# Energy optimization at  150 th step is :  -0.3712921898593088
# Energy optimization at final step is :  -0.3906221367344421

# %% [markdown]
# ##### The optiization results for the mitigated device is erroneous.

# %%
print("Exact ground state: ",energy_exact)
print("Ideally optimized after",max_iter," epochs: ",energy_ideal[-1])
print("Mitigated result after",max_iter," epochs: ",energy_mitigated[-1])
print("ideal optimization error:",np.abs((energy_ideal[-1] - energy_exact)/energy_exact))
print("mitigated optimization error:",np.abs((energy_mitigated[-1] - energy_exact)/energy_exact))
# Out:
# Exact ground state:  -3.0000000000000004
# Ideally optimized after 200  epochs:  -2.9998030393783326
# Mitigated result after 200  epochs:  -0.3906221367344421
# ideal optimization error: 6.56535405559507e-05
# mitigated optimization error: 0.8697926210885194

# %%
plt.figure(figsize=(10, 7))

plt.plot(energy_ideal, "-", label="VQE ideal", color = "m",linewidth = 0.9)
plt.plot(energy_noisy, "-", label="VQE noisy", color = "k",linewidth = 0.9)
plt.plot(energy_mitigated, "-", label="VQE mitigated", color = "b",linewidth = 0.9)
plt.plot(np.arange(stop=max_iter,step=1), [energy_exact]*max_iter, "-", label="E_exact", color = "r")
plt.legend(fontsize=10)

plt.xlabel("Iteration", fontsize=10)
plt.ylabel("Energy", fontsize=10)
plt.show()
